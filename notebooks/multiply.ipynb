# %%
def multiply(a, b):
    return a * b

a = 1
b = 3
print(f"Multiplying {a} and {b} gives: {multiply(a, b)}")

a = 2
b = 4
print(f"Multiplying {a} and {b} gives: {multiply(a, b)}")

a = 5
b = 6
print(f"Multiplying {a} and {b} gives: {multiply(a, b)}")
