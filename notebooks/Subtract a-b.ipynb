# %%
def subtract(a,b,):
    D = a - b
    print('The subtract is equal to: ', D)

subtract(1,3)
subtract(8,5)
subtract(150,100)
# Out:
# The subtract is equal to:  -2
# The subtract is equal to:  3
# The subtract is equal to:  50
